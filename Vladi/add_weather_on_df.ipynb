# %% [markdown]
# ## Associate for every lap, the average weather data info

# %%
import fastf1 as ff1
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm  # Per la barra di progresso (opzionale)
from scipy.stats import circmean

# %% [markdown]
# # Select a driver

# %%
piloti_per_anno = {
    2015: ["HAM", "ROS", "VET", "RAI", "BOT", "MAS", "ALO", "BUT", "RIC", "KVY", "PER", "HUL", "GRO", "MAL", "SAI", "VER", "ERI", "NAS"],
    2016: ["HAM", "ROS", "VET", "RAI", "BOT", "MAS", "ALO", "BUT", "RIC", "VER", "PER", "HUL", "GRO", "GUT", "SAI", "KVY", "ERI", "NAS", "WEH", "OCO"],
    2017: ["VET", "HAM", "BOT", "RAI", "VER", "RIC", "PER", "OCO", "HUL", "SAI", "STR", "MAS", "ALO", "VAN", "GRO", "MAG", "ERI", "WEH"],
    2018: ["HAM", "VET", "RAI", "BOT", "VER", "RIC", "PER", "OCO", "HUL", "SAI", "LEC", "ERI", "GRO", "MAG", "ALO", "VAN", "STR", "SIR"],
    2019: ["HAM", "BOT", "VET", "LEC", "VER", "GAS", "ALB", "RIC", "HUL", "SAI", "PER", "STR", "RAI", "GIO", "GRO", "MAG", "KUB", "RUS"],
    2020: ["HAM", "BOT", "VER", "ALB", "LEC", "VET", "PER", "STR", "RIC", "OCO", "SAI", "NOR", "RAI", "GIO", "GRO", "MAG", "RUS", "LAT"],
    2021: ["VER", "HAM", "BOT", "PER", "LEC", "SAI", "RIC", "NOR", "GAS", "TSU", "OCO", "ALO", "VET", "STR", "RAI", "GIO", "RUS", "LAT", "MSC", "MAZ"],
    2022: ["VER", "PER", "LEC", "SAI", "HAM", "RUS", "NOR", "RIC", "OCO", "ALO", "GAS", "TSU", "VET", "STR", "BOT", "ZHO", "MSC", "MAG", "ALB", "LAT"],
    2023: ["VER", "PER", "HAM", "RUS", "LEC", "SAI", "NOR", "PIA", "ALO", "STR", "GAS", "OCO", "ALB", "SAR", "BOT", "ZHO", "MAG", "HUL"],
    2024: ["VER", "PER", "HAM", "RUS", "LEC", "SAI", "NOR", "PIA", "ALO", "STR", "GAS", "OCO", "ALB", "SAR", "BOT", "ZHO", "MAG", "HUL", "RIC", "TSU"]
}

gp_per_anno = {
    2015: ["Australia", "Malaysia", "China", "Bahrain", "Spain", "Monaco", "Canada", "Austria", "Great Britain", "Hungary", "Belgium", "Monza", "Singapore", "Japan", "Russia", "Austin", "Mexico", "Brazil", "Abu Dhabi"],
    2016: ["Australia", "Bahrain", "China", "Russia", "Spain", "Monaco", "Canada", "Azerbaijan", "Austria", "Great Britain", "Hungary", "Germany", "Belgium", "Monza", "Singapore", "Malaysia", "Japan", "Austin", "Mexico", "Brazil", "Abu Dhabi"],
    2017: ["Australia", "China", "Bahrain", "Russia", "Spain", "Monaco", "Canada", "Azerbaijan", "Austria", "Great Britain", "Hungary", "Belgium", "Monza", "Singapore", "Malaysia", "Japan", "Austin", "Mexico", "Brazil", "Abu Dhabi"],
    2018: ["Australia", "Bahrain", "China", "Azerbaijan", "Spain", "Monaco", "Canada", "France", "Austria", "Great Britain", "Germany", "Hungary", "Belgium", "Monza", "Singapore", "Russia", "Japan", "Austin", "Mexico", "Brazil", "Abu Dhabi"],
    2019: ["Australia", "Bahrain", "China", "Azerbaijan", "Spain", "Monaco", "Canada", "France", "Austria", "Great Britain", "Germany", "Hungary", "Belgium", "Monza", "Singapore", "Russia", "Japan", "Mexico", "Austin", "Brazil", "Abu Dhabi"],
    2020: ["Austria", "Styria", "Hungary", "Great Britain", "70thAnniversary", "Spain", "Belgium", "Monza", "Tuscany", "Russia", "Eifel", "Portugal", "Imola", "Turkey", "Bahrain", "Sakhir", "Abu Dhabi"],
    2021: ["Bahrain", "Imola", "Portugal", "Spain", "Monaco", "Azerbaijan", "France", "Styria", "Austria", "Great Britain", "Hungary", "Belgium", "Zandvoort", "Monza", "Russia", "Turkey", "Austin", "Mexico", "Brazil", "Qatar", "Saudi Arabia", "Abu Dhabi"],
    2022: ["Bahrain", "Saudi Arabia", "Australia", "Imola", "Miami", "Spain", "Monaco", "Azerbaijan", "Canada", "Great Britain", "Austria", "France", "Hungary", "Belgium", "Zandvoort", "Monza", "Singapore", "Japan", "Austin", "Mexico", "Brazil", "Abu Dhabi"],
    2023: ["Bahrain", "Saudi Arabia", "Australia", "Azerbaijan", "Miami", "Monaco", "Spain", "Canada", "Austria", "Great Britain", "Hungary", "Belgium", "Zandvoort", "Monza", "Singapore", "Japan", "Qatar", "Austin", "Mexico", "Brazil", "LasVegas", "Abu Dhabi"],
    2024: ["Bahrain", "Saudi Arabia", "Australia", "Japan", "China", "Miami", "Imola", "Monaco", "Canada", "Spain", "Austria", "Great Britain", "Hungary", "Belgium", "Zandvoort", "Monza", "Azerbaijan", "Singapore", "Austin", "Mexico", "Brazil", "LasVegas", "Qatar", "Abu Dhabi"]
}
# Funzione per scegliere da un menu
def scegli_opzione(opzioni, messaggio):
    print(f"\n{messaggio}:")
    for i, opzione in enumerate(opzioni, 1):
        print(f"{i}. {opzione}")
    
    while True:
        try:
            scelta = int(input("Inserisci il numero: "))
            if 1 <= scelta <= len(opzioni):
                return opzioni[scelta - 1]
            print("Numero non valido.")
        except ValueError:
            print("Input non valido. Riprova.")

# --- Scelta anno ---
year = scegli_opzione(list(gp_per_anno.keys()), "Scegli l'anno")

# --- Scelta GP ---
gp = scegli_opzione(gp_per_anno[anno], f"Scegli il GP del {anno}")

# --- Scelta pilota (lista fissa per l'anno) ---
driver = scegli_opzione(piloti_per_anno[anno], f"Scegli il pilota per il {anno}")

# Risultato finale
print(f"\nHai selezionato: {driver} al GP di {gp} nel {year}!")
# Out:
# Scegli l'anno:
# 1. 2015
# 2. 2016
# 3. 2017
# 4. 2018
# 5. 2019
# 6. 2020
# 7. 2021
# 8. 2022
# 9. 2023
# 10. 2024
#
# Scegli il GP del 2016:
# 1. Australia
# 2. Bahrain
# 3. China
# 4. Russia
# 5. Spain
# 6. Monaco
# 7. Canada
# 8. Azerbaijan
# 9. Austria
# 10. Great Britain
# 11. Hungary
# 12. Germany
# 13. Belgium
# 14. Monza
# 15. Singapore
# 16. Malaysia
# 17. Japan
# 18. Austin
# 19. Mexico
# 20. Brazil
# 21. Abu Dhabi
#
# Scegli il pilota per il 2016:
# 1. HAM
# 2. ROS
# 3. VET
# 4. RAI
# 5. BOT
# 6. MAS
# 7. ALO
# 8. BUT
# 9. RIC
# 10. VER
# 11. PER
# 12. HUL
# 13. GRO
# 14. GUT
# 15. SAI
# 16. KVY
# 17. ERI
# 18. NAS
# 19. WEH
# 20. OCO
#
# Hai selezionato: ROS al GP di Australia nel 2018!

# %% [markdown]
# # Create a copy of driver dataframe

# %%
session = ff1.get_session(2023, 'Monaco', 'R')
sessione = session.load()
weather_data = session.weather_data
driver = 'SAR'
driver_laps = session.laps.pick_drivers(driver)
# Out:
# core           INFO 	Loading data for Monaco Grand Prix - Race [v3.4.5]
# req            INFO 	Using cached data for session_info
# req            INFO 	Using cached data for driver_info
# req            INFO 	Using cached data for session_status_data
# req            INFO 	Using cached data for lap_count
# req            INFO 	Using cached data for track_status_data
# req            INFO 	Using cached data for _extended_timing_data
# req            INFO 	Using cached data for timing_app_data
# core           INFO 	Processing timing data...
# req            INFO 	Using cached data for car_data
# req            INFO 	Using cached data for position_data
# req            INFO 	Using cached data for weather_data
# req            INFO 	Using cached data for race_control_messages
# core           INFO 	Finished loading data for 20 drivers: ['1', '14', '31', '44', '63', '16', '10', '55', '4', '81', '77', '21', '24', '23', '22', '11', '27', '2', '20', '18']

# %% [markdown]
# # Add data from weather df

# %%
driver_laps['AirTemp'] = np.nan
driver_laps['Humidity'] = np.nan
driver_laps['Pressure'] = np.nan
driver_laps['Rainfall'] = np.nan
driver_laps['Track_Temp'] = np.nan
driver_laps['WindDirection'] = np.nan
driver_laps['WindSpeed'] = np.nan
#Creo il contatore partendo dalla prima riga
i = 0

for i in range(len(driver_laps)):
    #Definisco la variabile lap_start_driver, quando inizia il giro in corso(i)
    lap_start_driver = driver_laps['LapStartTime'].iloc[i]
    #Definisco la variabile lap_finish_driver, quando finisce il giro in corso(i)
    lap_finish_driver = driver_laps['Time'].iloc[i]
    #Stampo i valori
    print('Il giro inizia : ', lap_start_driver)
    print('Il giro finisce a: ', lap_finish_driver)

    # Seleziona solo le righe con Time tra lap_start_driver e lap_finish_driver
    weather_first_lap = weather_data[
        (weather_data['Time'] >= lap_start_driver) & 
        (weather_data['Time'] <= lap_finish_driver)
    ]
    print(weather_first_lap)

    ###############################################################################

    j = 0
    temperatura = 0
    humidity = 0
    rain = False
    track_temp = 0
    pressure = 0
    wind_speed = 0
    wind_direction = 0
    for j in range(len(weather_first_lap)):

        #Calcolo la temperatura media
        temperatura = temperatura + weather_first_lap['AirTemp'].iloc[j]
        
        #Calcolo umidità media
        humidity = humidity + weather_first_lap['Humidity'].iloc[j]

        #Calocolo pioggia True/False
        if weather_first_lap['Rainfall'].iloc[j] == True:
            rain = True
        
        #Calculate AVG track Temp
        track_temp = track_temp + weather_first_lap['TrackTemp'].iloc[j]

        #Calculate AVG Pressure
        pressure = pressure + weather_first_lap['Pressure'].iloc[j]

        #Calculate AVG Wind Speed
        wind_speed = wind_speed + weather_first_lap['WindSpeed'].iloc[j]

        #Calculate AVG Wind Direction
        wind_direction = wind_direction + weather_first_lap['WindDirection'].iloc[j]


        j = j + 1

    
    air_temp_avg = temperatura / len(weather_first_lap)
    print('Temperatura_media ',air_temp_avg)
    humidity_avg = humidity / len(weather_first_lap)
    print('Umidità ',humidity_avg)
    print('Piove? ',rain)
    trackTemp_AVG = track_temp / len(weather_first_lap)
    print('TrackTemp AVG ', trackTemp_AVG)
    pressure_avg = pressure / len(weather_first_lap)
    print('Pressure AVG', pressure_avg)
    wind_speed_avg = wind_speed / len(weather_first_lap)
    print('Wind Speed AVG', wind_speed_avg)
    wind_direction_avg = wind_direction / len(weather_first_lap)
    print('Wind Direction AVG', wind_direction_avg)

    driver_laps.iloc[i, driver_laps.columns.get_loc('AirTemp')] = air_temp_avg
    driver_laps.iloc[i, driver_laps.columns.get_loc('Humidity')] = humidity_avg
    driver_laps.iloc[i, driver_laps.columns.get_loc('Pressure')] = pressure_avg
    driver_laps.iloc[i, driver_laps.columns.get_loc('Rainfall')] = rain
    driver_laps.iloc[i, driver_laps.columns.get_loc('Track_Temp')] = trackTemp_AVG
    driver_laps.iloc[i, driver_laps.columns.get_loc('WindDirection')]  = wind_direction_avg
    driver_laps.iloc[i, driver_laps.columns.get_loc('WindSpeed')] = wind_speed_avg
# Out:
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['AirTemp'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['Humidity'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['Pressure'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['Rainfall'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['Track_Temp'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['WindDirection'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   driver_laps['WindSpeed'] = np.nan
# C:\Users\calin\AppData\Local\Temp\ipykernel_3724\2356143213.py:82: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'False' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   driver_laps.iloc[i, driver_laps.columns.get_loc('Rainfall')] = rain
# Il giro inizia :  0 days 01:02:02.950000
# Il giro finisce a:  0 days 01:03:40.909000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 62 0 days 01:02:42.715000     25.2      44.0    1013.4     False       43.1
#
#     WindDirection  WindSpeed
# 62            153        0.8
# Temperatura_media  25.2
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  43.1
# Pressure AVG 1013.4
# Wind Speed AVG 0.8
# Wind Direction AVG 153.0
# Il giro inizia :  0 days 01:03:40.909000
# Il giro finisce a:  0 days 01:05:00.567000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 63 0 days 01:03:42.714000     25.2      44.0    1013.4     False       43.1
# 64 0 days 01:04:42.729000     25.2      45.0    1013.5     False       42.8
#
#     WindDirection  WindSpeed
# 63             48        1.0
# 64             66        0.8
# Temperatura_media  25.2
# Umidità  44.5
# Piove?  False
# TrackTemp AVG  42.95
# Pressure AVG 1013.45
# Wind Speed AVG 0.9
# Wind Direction AVG 57.0
# Il giro inizia :  0 days 01:05:00.567000
# Il giro finisce a:  0 days 01:06:20.786000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 65 0 days 01:05:42.712000     25.3      45.0    1013.4     False       42.8
#
#     WindDirection  WindSpeed
# 65             18        1.0
# Temperatura_media  25.3
# Umidità  45.0
# Piove?  False
# TrackTemp AVG  42.8
# Pressure AVG 1013.4
# Wind Speed AVG 1.0
# Wind Direction AVG 18.0
# Il giro inizia :  0 days 01:06:20.786000
# Il giro finisce a:  0 days 01:07:41.032000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 66 0 days 01:06:42.711000     25.4      45.0    1013.5     False       42.8
#
#     WindDirection  WindSpeed
# 66            115        1.0
# Temperatura_media  25.4
# Umidità  45.0
# Piove?  False
# TrackTemp AVG  42.8
# Pressure AVG 1013.5
# Wind Speed AVG 1.0
# Wind Direction AVG 115.0
# Il giro inizia :  0 days 01:07:41.032000
# Il giro finisce a:  0 days 01:09:01.246000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 67 0 days 01:07:42.710000     25.5      44.0    1013.5     False       42.4
# 68 0 days 01:08:42.709000     25.4      44.0    1013.5     False       42.4
#
#     WindDirection  WindSpeed
# 67            161        1.3
# 68            132        1.0
# Temperatura_media  25.45
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  42.4
# Pressure AVG 1013.5
# Wind Speed AVG 1.15
# Wind Direction AVG 146.5
# Il giro inizia :  0 days 01:09:01.246000
# Il giro finisce a:  0 days 01:10:20.558000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 69 0 days 01:09:42.723000     25.4      44.0    1013.5     False       41.6
#
#     WindDirection  WindSpeed
# 69             76        0.8
# Temperatura_media  25.4
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  41.6
# Pressure AVG 1013.5
# Wind Speed AVG 0.8
# Wind Direction AVG 76.0
# Il giro inizia :  0 days 01:10:20.558000
# Il giro finisce a:  0 days 01:11:39.797000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 70 0 days 01:10:42.722000     25.4      44.0    1013.5     False       41.4
#
#     WindDirection  WindSpeed
# 70             50        0.6
# Temperatura_media  25.4
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  41.4
# Pressure AVG 1013.5
# Wind Speed AVG 0.6
# Wind Direction AVG 50.0
# Il giro inizia :  0 days 01:11:39.797000
# Il giro finisce a:  0 days 01:12:58.744000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 71 0 days 01:11:42.721000     25.4      44.0    1013.5     False       40.9
# 72 0 days 01:12:42.720000     25.4      44.0    1013.5     False       41.0
#
#     WindDirection  WindSpeed
# 71            359        0.8
# 72            147        1.2
# Temperatura_media  25.4
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  40.95
# Pressure AVG 1013.5
# Wind Speed AVG 1.0
# Wind Direction AVG 253.0
# Il giro inizia :  0 days 01:12:58.744000
# Il giro finisce a:  0 days 01:14:18.273000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 73 0 days 01:13:42.719000     25.5      43.0    1013.5     False       41.2
#
#     WindDirection  WindSpeed
# 73            140        1.2
# Temperatura_media  25.5
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  41.2
# Pressure AVG 1013.5
# Wind Speed AVG 1.2
# Wind Direction AVG 140.0
# Il giro inizia :  0 days 01:14:18.273000
# Il giro finisce a:  0 days 01:15:38.607000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 74 0 days 01:14:42.718000     25.5      42.0    1013.5     False       40.9
#
#     WindDirection  WindSpeed
# 74            137        2.2
# Temperatura_media  25.5
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  40.9
# Pressure AVG 1013.5
# Wind Speed AVG 2.2
# Wind Direction AVG 137.0
# Il giro inizia :  0 days 01:15:38.607000
# Il giro finisce a:  0 days 01:16:58.696000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 75 0 days 01:15:42.717000     25.4      43.0    1013.5     False       40.2
# 76 0 days 01:16:42.700000     25.3      44.0    1013.5     False       40.0
#
#     WindDirection  WindSpeed
# 75            142        1.2
# 76              1        0.6
# Temperatura_media  25.35
# Umidità  43.5
# Piove?  False
# TrackTemp AVG  40.1
# Pressure AVG 1013.5
# Wind Speed AVG 0.8999999999999999
# Wind Direction AVG 71.5
# Il giro inizia :  0 days 01:16:58.696000
# Il giro finisce a:  0 days 01:18:19.334000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 77 0 days 01:17:42.715000     25.3      44.0    1013.5     False       40.0
#
#     WindDirection  WindSpeed
# 77              0        1.7
# Temperatura_media  25.3
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  40.0
# Pressure AVG 1013.5
# Wind Speed AVG 1.7
# Wind Direction AVG 0.0
# Il giro inizia :  0 days 01:18:19.334000
# Il giro finisce a:  0 days 01:19:40.036000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 78 0 days 01:18:42.714000     25.4      43.0    1013.5     False       40.1
#
#     WindDirection  WindSpeed
# 78            136        0.6
# Temperatura_media  25.4
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  40.1
# Pressure AVG 1013.5
# Wind Speed AVG 0.6
# Wind Direction AVG 136.0
# Il giro inizia :  0 days 01:19:40.036000
# Il giro finisce a:  0 days 01:21:00.354000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 79 0 days 01:19:42.713000     25.4      43.0    1013.5     False       40.1
# 80 0 days 01:20:42.712000     25.3      43.0    1013.5     False       39.9
#
#     WindDirection  WindSpeed
# 79            146        1.2
# 80            148        0.8
# Temperatura_media  25.35
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  40.0
# Pressure AVG 1013.5
# Wind Speed AVG 1.0
# Wind Direction AVG 147.0
# Il giro inizia :  0 days 01:21:00.354000
# Il giro finisce a:  0 days 01:22:20.634000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 81 0 days 01:21:42.742000     25.3      44.0    1013.7     False       39.9
#
#     WindDirection  WindSpeed
# 81            134        1.6
# Temperatura_media  25.3
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  39.9
# Pressure AVG 1013.7
# Wind Speed AVG 1.6
# Wind Direction AVG 134.0
# Il giro inizia :  0 days 01:22:20.634000
# Il giro finisce a:  0 days 01:23:41.105000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 82 0 days 01:22:42.710000     25.3      44.0    1013.5     False       39.5
#
#     WindDirection  WindSpeed
# 82            129        0.8
# Temperatura_media  25.3
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  39.5
# Pressure AVG 1013.5
# Wind Speed AVG 0.8
# Wind Direction AVG 129.0
# Il giro inizia :  0 days 01:23:41.105000
# Il giro finisce a:  0 days 01:25:04.341000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 83 0 days 01:23:42.724000     25.3      44.0    1013.5     False       39.5
# 84 0 days 01:24:42.723000     25.2      44.0    1013.5     False       39.8
#
#     WindDirection  WindSpeed
# 83            168        0.8
# 84            145        0.8
# Temperatura_media  25.25
# Umidità  44.0
# Piove?  False
# TrackTemp AVG  39.65
# Pressure AVG 1013.5
# Wind Speed AVG 0.8
# Wind Direction AVG 156.5
# Il giro inizia :  0 days 01:25:04.341000
# Il giro finisce a:  0 days 01:26:25.751000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 85 0 days 01:25:42.722000     25.3      43.0    1013.5     False       39.8
#
#     WindDirection  WindSpeed
# 85            104        1.5
# Temperatura_media  25.3
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  39.8
# Pressure AVG 1013.5
# Wind Speed AVG 1.5
# Wind Direction AVG 104.0
# Il giro inizia :  0 days 01:26:25.751000
# Il giro finisce a:  0 days 01:27:48.079000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 86 0 days 01:26:42.737000     25.3      42.0    1013.5     False       39.9
# 87 0 days 01:27:42.751000     25.3      42.0    1013.5     False       39.9
#
#     WindDirection  WindSpeed
# 86            132        0.6
# 87            142        1.2
# Temperatura_media  25.3
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  39.9
# Pressure AVG 1013.5
# Wind Speed AVG 0.8999999999999999
# Wind Direction AVG 137.0
# Il giro inizia :  0 days 01:27:48.079000
# Il giro finisce a:  0 days 01:29:25.290000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 88 0 days 01:28:42.766000     25.3      43.0    1013.5     False       39.7
#
#     WindDirection  WindSpeed
# 88             91        2.0
# Temperatura_media  25.3
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  39.7
# Pressure AVG 1013.5
# Wind Speed AVG 2.0
# Wind Direction AVG 91.0
# Il giro inizia :  0 days 01:29:25.290000
# Il giro finisce a:  0 days 01:30:46.936000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 89 0 days 01:29:42.780000     25.4      43.0    1013.5     False       39.2
# 90 0 days 01:30:42.779000     25.4      43.0    1013.5     False       39.1
#
#     WindDirection  WindSpeed
# 89            154        1.3
# 90            125        1.6
# Temperatura_media  25.4
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  39.150000000000006
# Pressure AVG 1013.5
# Wind Speed AVG 1.4500000000000002
# Wind Direction AVG 139.5
# Il giro inizia :  0 days 01:30:46.936000
# Il giro finisce a:  0 days 01:32:04.419000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 91 0 days 01:31:42.794000     25.3      43.0    1013.4     False       39.1
#
#     WindDirection  WindSpeed
# 91            151        1.2
# Temperatura_media  25.3
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  39.1
# Pressure AVG 1013.4
# Wind Speed AVG 1.2
# Wind Direction AVG 151.0
# Il giro inizia :  0 days 01:32:04.419000
# Il giro finisce a:  0 days 01:33:42.614000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 92 0 days 01:32:42.808000     25.4      42.0    1013.4     False       39.0
#
#     WindDirection  WindSpeed
# 92            141        1.1
# Temperatura_media  25.4
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  39.0
# Pressure AVG 1013.4
# Wind Speed AVG 1.1
# Wind Direction AVG 141.0
# Il giro inizia :  0 days 01:33:42.614000
# Il giro finisce a:  0 days 01:35:03.296000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 93 0 days 01:33:42.823000     25.4      42.0    1013.2     False       39.0
# 94 0 days 01:34:42.837000     25.4      42.0    1013.4     False       38.8
#
#     WindDirection  WindSpeed
# 93            140        1.5
# 94            152        1.8
# Temperatura_media  25.4
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  38.9
# Pressure AVG 1013.3
# Wind Speed AVG 1.65
# Wind Direction AVG 146.0
# Il giro inizia :  0 days 01:35:03.296000
# Il giro finisce a:  0 days 01:36:21.190000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 95 0 days 01:35:42.852000     25.3      42.0    1013.2     False       38.6
#
#     WindDirection  WindSpeed
# 95            132        1.2
# Temperatura_media  25.3
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  38.6
# Pressure AVG 1013.2
# Wind Speed AVG 1.2
# Wind Direction AVG 132.0
# Il giro inizia :  0 days 01:36:21.190000
# Il giro finisce a:  0 days 01:37:39.223000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 96 0 days 01:36:42.851000     25.3      42.0    1013.2     False       38.8
#
#     WindDirection  WindSpeed
# 96            131        0.6
# Temperatura_media  25.3
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  38.8
# Pressure AVG 1013.2
# Wind Speed AVG 0.6
# Wind Direction AVG 131.0
# Il giro inizia :  0 days 01:37:39.223000
# Il giro finisce a:  0 days 01:38:57.098000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 97 0 days 01:37:42.850000     25.4      42.0    1013.4     False       39.1
# 98 0 days 01:38:42.849000     25.4      41.0    1013.2     False       39.1
#
#     WindDirection  WindSpeed
# 97            158        1.2
# 98            134        1.0
# Temperatura_media  25.4
# Umidità  41.5
# Piove?  False
# TrackTemp AVG  39.1
# Pressure AVG 1013.3
# Wind Speed AVG 1.1
# Wind Direction AVG 146.0
# Il giro inizia :  0 days 01:38:57.098000
# Il giro finisce a:  0 days 01:40:14.838000
#                      Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 99 0 days 01:39:42.848000     25.4      41.0    1013.2     False       38.9
#
#     WindDirection  WindSpeed
# 99            166        0.8
# Temperatura_media  25.4
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  38.9
# Pressure AVG 1013.2
# Wind Speed AVG 0.8
# Wind Direction AVG 166.0
# Il giro inizia :  0 days 01:40:14.838000
# Il giro finisce a:  0 days 01:41:32.591000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 100 0 days 01:40:42.847000     25.5      41.0    1013.2     False       38.8
#
#      WindDirection  WindSpeed
# 100             81        1.1
# Temperatura_media  25.5
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  38.8
# Pressure AVG 1013.2
# Wind Speed AVG 1.1
# Wind Direction AVG 81.0
# Il giro inizia :  0 days 01:41:32.591000
# Il giro finisce a:  0 days 01:42:50.126000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 101 0 days 01:41:42.846000     25.6      41.0    1013.4     False       38.6
# 102 0 days 01:42:42.844000     25.6      40.0    1013.4     False       38.4
#
#      WindDirection  WindSpeed
# 101            168        0.8
# 102            110        1.0
# Temperatura_media  25.6
# Umidità  40.5
# Piove?  False
# TrackTemp AVG  38.5
# Pressure AVG 1013.4
# Wind Speed AVG 0.9
# Wind Direction AVG 139.0
# Il giro inizia :  0 days 01:42:50.126000
# Il giro finisce a:  0 days 01:44:07.619000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 103 0 days 01:43:42.843000     25.6      40.0    1013.5     False       38.4
#
#      WindDirection  WindSpeed
# 103            137        1.0
# Temperatura_media  25.6
# Umidità  40.0
# Piove?  False
# TrackTemp AVG  38.4
# Pressure AVG 1013.5
# Wind Speed AVG 1.0
# Wind Direction AVG 137.0
# Il giro inizia :  0 days 01:44:07.619000
# Il giro finisce a:  0 days 01:45:24.921000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 104 0 days 01:44:42.842000     25.6      40.0    1013.4     False       38.4
#
#      WindDirection  WindSpeed
# 104            156        1.0
# Temperatura_media  25.6
# Umidità  40.0
# Piove?  False
# TrackTemp AVG  38.4
# Pressure AVG 1013.4
# Wind Speed AVG 1.0
# Wind Direction AVG 156.0
# Il giro inizia :  0 days 01:45:24.921000
# Il giro finisce a:  0 days 01:46:42.265000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 105 0 days 01:45:42.857000     25.5      41.0    1013.5     False       38.4
#
#      WindDirection  WindSpeed
# 105            147        1.2
# Temperatura_media  25.5
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  38.4
# Pressure AVG 1013.5
# Wind Speed AVG 1.2
# Wind Direction AVG 147.0
# Il giro inizia :  0 days 01:46:42.265000
# Il giro finisce a:  0 days 01:47:59.931000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 106 0 days 01:46:42.856000     25.5      41.0    1013.4     False       37.9
# 107 0 days 01:47:42.870000     25.5      41.0    1013.4     False       37.9
#
#      WindDirection  WindSpeed
# 106             92        1.0
# 107            174        1.1
# Temperatura_media  25.5
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  37.9
# Pressure AVG 1013.4
# Wind Speed AVG 1.05
# Wind Direction AVG 133.0
# Il giro inizia :  0 days 01:47:59.931000
# Il giro finisce a:  0 days 01:49:18.569000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 108 0 days 01:48:42.869000     25.4      41.0    1013.4     False       37.9
#
#      WindDirection  WindSpeed
# 108            154        1.6
# Temperatura_media  25.4
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  37.9
# Pressure AVG 1013.4
# Wind Speed AVG 1.6
# Wind Direction AVG 154.0
# Il giro inizia :  0 days 01:49:18.569000
# Il giro finisce a:  0 days 01:50:35.941000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 109 0 days 01:49:42.884000     25.3      41.0    1013.4     False       37.6
#
#      WindDirection  WindSpeed
# 109            145        1.1
# Temperatura_media  25.3
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  37.6
# Pressure AVG 1013.4
# Wind Speed AVG 1.1
# Wind Direction AVG 145.0
# Il giro inizia :  0 days 01:50:35.941000
# Il giro finisce a:  0 days 01:51:53.324000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 110 0 days 01:50:42.914000     25.3      41.0    1013.2     False       37.5
# 111 0 days 01:51:42.897000     25.3      41.0    1013.4     False       36.8
#
#      WindDirection  WindSpeed
# 110            140        1.3
# 111             67        0.6
# Temperatura_media  25.3
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  37.15
# Pressure AVG 1013.3
# Wind Speed AVG 0.95
# Wind Direction AVG 103.5
# Il giro inizia :  0 days 01:51:53.324000
# Il giro finisce a:  0 days 01:53:13.341000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 112 0 days 01:52:42.912000     25.3      41.0    1013.4     False       36.8
#
#      WindDirection  WindSpeed
# 112            158        1.2
# Temperatura_media  25.3
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  36.8
# Pressure AVG 1013.4
# Wind Speed AVG 1.2
# Wind Direction AVG 158.0
# Il giro inizia :  0 days 01:53:13.341000
# Il giro finisce a:  0 days 01:54:34.376000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 113 0 days 01:53:42.926000     25.3      41.0    1013.2     False       36.7
#
#      WindDirection  WindSpeed
# 113            143        1.0
# Temperatura_media  25.3
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  36.7
# Pressure AVG 1013.2
# Wind Speed AVG 1.0
# Wind Direction AVG 143.0
# Il giro inizia :  0 days 01:54:34.376000
# Il giro finisce a:  0 days 01:55:53.845000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 114 0 days 01:54:42.941000     25.3      41.0    1013.4     False       36.8
# 115 0 days 01:55:42.940000     25.3      42.0    1013.2     False       36.5
#
#      WindDirection  WindSpeed
# 114            152        1.2
# 115            139        1.2
# Temperatura_media  25.3
# Umidità  41.5
# Piove?  False
# TrackTemp AVG  36.65
# Pressure AVG 1013.3
# Wind Speed AVG 1.2
# Wind Direction AVG 145.5
# Il giro inizia :  0 days 01:55:53.845000
# Il giro finisce a:  0 days 01:57:12.364000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 116 0 days 01:56:42.954000     25.3      41.0    1013.2     False       36.5
#
#      WindDirection  WindSpeed
# 116            109        1.2
# Temperatura_media  25.3
# Umidità  41.0
# Piove?  False
# TrackTemp AVG  36.5
# Pressure AVG 1013.2
# Wind Speed AVG 1.2
# Wind Direction AVG 109.0
# Il giro inizia :  0 days 01:57:12.364000
# Il giro finisce a:  0 days 01:58:30.989000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 117 0 days 01:57:42.969000     25.2      42.0    1013.4     False       36.4
#
#      WindDirection  WindSpeed
# 117            151        0.8
# Temperatura_media  25.2
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  36.4
# Pressure AVG 1013.4
# Wind Speed AVG 0.8
# Wind Direction AVG 151.0
# Il giro inizia :  0 days 01:58:30.989000
# Il giro finisce a:  0 days 01:59:49.762000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 118 0 days 01:58:42.968000     25.2      42.0    1013.4     False       36.3
# 119 0 days 01:59:42.967000     25.2      42.0    1013.4     False       36.3
#
#      WindDirection  WindSpeed
# 118            155        1.1
# 119              0        0.0
# Temperatura_media  25.2
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  36.3
# Pressure AVG 1013.4
# Wind Speed AVG 0.55
# Wind Direction AVG 77.5
# Il giro inizia :  0 days 01:59:49.762000
# Il giro finisce a:  0 days 02:01:11.887000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 120 0 days 02:00:42.981000     25.1      43.0    1013.4     False       36.1
#
#      WindDirection  WindSpeed
# 120            153        0.8
# Temperatura_media  25.1
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  36.1
# Pressure AVG 1013.4
# Wind Speed AVG 0.8
# Wind Direction AVG 153.0
# Il giro inizia :  0 days 02:01:11.887000
# Il giro finisce a:  0 days 02:02:31.505000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 121 0 days 02:01:42.980000     25.0      43.0    1013.2     False       36.1
#
#      WindDirection  WindSpeed
# 121            131        0.8
# Temperatura_media  25.0
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  36.1
# Pressure AVG 1013.2
# Wind Speed AVG 0.8
# Wind Direction AVG 131.0
# Il giro inizia :  0 days 02:02:31.505000
# Il giro finisce a:  0 days 02:03:50.533000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 122 0 days 02:02:42.979000     25.0      43.0    1013.4     False       36.0
# 123 0 days 02:03:42.963000     25.1      42.0    1013.4     False       36.0
#
#      WindDirection  WindSpeed
# 122             70        0.8
# 123            145        1.0
# Temperatura_media  25.05
# Umidità  42.5
# Piove?  False
# TrackTemp AVG  36.0
# Pressure AVG 1013.4
# Wind Speed AVG 0.9
# Wind Direction AVG 107.5
# Il giro inizia :  0 days 02:03:50.533000
# Il giro finisce a:  0 days 02:05:09.443000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 124 0 days 02:04:42.977000     25.0      42.0    1013.2     False       35.9
#
#      WindDirection  WindSpeed
# 124            128        2.0
# Temperatura_media  25.0
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  35.9
# Pressure AVG 1013.2
# Wind Speed AVG 2.0
# Wind Direction AVG 128.0
# Il giro inizia :  0 days 02:05:09.443000
# Il giro finisce a:  0 days 02:06:28.655000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 125 0 days 02:05:42.976000     25.0      42.0    1013.2     False       35.8
#
#      WindDirection  WindSpeed
# 125            163        1.0
# Temperatura_media  25.0
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  35.8
# Pressure AVG 1013.2
# Wind Speed AVG 1.0
# Wind Direction AVG 163.0
# Il giro inizia :  0 days 02:06:28.655000
# Il giro finisce a:  0 days 02:07:50.783000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 126 0 days 02:06:42.975000     25.0      43.0    1013.4     False       35.8
# 127 0 days 02:07:42.974000     25.0      43.0    1013.2     False       35.7
#
#      WindDirection  WindSpeed
# 126            158        0.6
# 127            130        1.1
# Temperatura_media  25.0
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  35.75
# Pressure AVG 1013.3
# Wind Speed AVG 0.8500000000000001
# Wind Direction AVG 144.0
# Il giro inizia :  0 days 02:07:50.783000
# Il giro finisce a:  0 days 02:09:13.903000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 128 0 days 02:08:42.973000     25.0      43.0    1013.4     False       35.7
#
#      WindDirection  WindSpeed
# 128              0        0.4
# Temperatura_media  25.0
# Umidità  43.0
# Piove?  False
# TrackTemp AVG  35.7
# Pressure AVG 1013.4
# Wind Speed AVG 0.4
# Wind Direction AVG 0.0
# Il giro inizia :  0 days 02:09:13.903000
# Il giro finisce a:  0 days 02:10:46.288000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 129 0 days 02:09:42.972000     25.0      42.0    1013.2     False       35.3
# 130 0 days 02:10:42.971000     24.9      42.0    1013.2     False       35.2
#
#      WindDirection  WindSpeed
# 129             97        0.5
# 130            172        1.2
# Temperatura_media  24.95
# Umidità  42.0
# Piove?  False
# TrackTemp AVG  35.25
# Pressure AVG 1013.2
# Wind Speed AVG 0.85
# Wind Direction AVG 134.5
# Il giro inizia :  0 days 02:10:46.288000
# Il giro finisce a:  0 days 02:12:44.206000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 131 0 days 02:11:42.970000     24.8      42.0    1013.2      True       35.1
# 132 0 days 02:12:42.968000     24.7      42.0    1013.2      True       34.9
#
#      WindDirection  WindSpeed
# 131             75        0.6
# 132            133        0.8
# Temperatura_media  24.75
# Umidità  42.0
# Piove?  True
# TrackTemp AVG  35.0
# Pressure AVG 1013.2
# Wind Speed AVG 0.7
# Wind Direction AVG 104.0
# Il giro inizia :  0 days 02:12:44.206000
# Il giro finisce a:  0 days 02:14:26.247000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 133 0 days 02:13:42.967000     24.7      43.0    1013.2      True       34.7
#
#      WindDirection  WindSpeed
# 133              0        0.8
# Temperatura_media  24.7
# Umidità  43.0
# Piove?  True
# TrackTemp AVG  34.7
# Pressure AVG 1013.2
# Wind Speed AVG 0.8
# Wind Direction AVG 0.0
# Il giro inizia :  0 days 02:14:26.247000
# Il giro finisce a:  0 days 02:16:05.053000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 134 0 days 02:14:42.982000     24.6      43.0    1013.2      True       34.5
# 135 0 days 02:15:42.965000     24.6      44.0    1013.2      True       34.0
#
#      WindDirection  WindSpeed
# 134            217        0.5
# 135            201        0.8
# Temperatura_media  24.6
# Umidità  43.5
# Piove?  True
# TrackTemp AVG  34.25
# Pressure AVG 1013.2
# Wind Speed AVG 0.65
# Wind Direction AVG 209.0
# Il giro inizia :  0 days 02:16:05.053000
# Il giro finisce a:  0 days 02:17:46.131000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 136 0 days 02:16:42.964000     24.5      45.0    1013.2      True       33.9
# 137 0 days 02:17:42.979000     24.3      48.0    1013.2      True       32.8
#
#      WindDirection  WindSpeed
# 136            104        0.6
# 137            276        0.5
# Temperatura_media  24.4
# Umidità  46.5
# Piove?  True
# TrackTemp AVG  33.349999999999994
# Pressure AVG 1013.2
# Wind Speed AVG 0.55
# Wind Direction AVG 190.0
# Il giro inizia :  0 days 02:17:46.131000
# Il giro finisce a:  0 days 02:19:28.416000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 138 0 days 02:18:42.978000     24.0      49.0    1013.2      True       31.7
#
#      WindDirection  WindSpeed
# 138            147        0.6
# Temperatura_media  24.0
# Umidità  49.0
# Piove?  True
# TrackTemp AVG  31.7
# Pressure AVG 1013.2
# Wind Speed AVG 0.6
# Wind Direction AVG 147.0
# Il giro inizia :  0 days 02:19:28.416000
# Il giro finisce a:  0 days 02:21:26.479000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 139 0 days 02:19:43.039000     24.0      51.0    1013.2      True       31.3
# 140 0 days 02:20:42.976000     24.0      52.0    1013.2      True       30.1
#
#      WindDirection  WindSpeed
# 139              0        1.2
# 140            127        0.6
# Temperatura_media  24.0
# Umidità  51.5
# Piove?  True
# TrackTemp AVG  30.700000000000003
# Pressure AVG 1013.2
# Wind Speed AVG 0.8999999999999999
# Wind Direction AVG 63.5
# Il giro inizia :  0 days 02:21:26.479000
# Il giro finisce a:  0 days 02:23:09.078000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 141 0 days 02:21:42.974000     24.0      50.0    1013.2      True       29.7
# 142 0 days 02:22:42.973000     23.9      51.0    1013.2      True       29.6
#
#      WindDirection  WindSpeed
# 141            150        0.8
# 142            189        1.2
# Temperatura_media  23.95
# Umidità  50.5
# Piove?  True
# TrackTemp AVG  29.65
# Pressure AVG 1013.2
# Wind Speed AVG 1.0
# Wind Direction AVG 169.5
# Il giro inizia :  0 days 02:23:09.078000
# Il giro finisce a:  0 days 02:24:52.765000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 143 0 days 02:23:42.972000     23.8      47.0    1013.2      True       29.5
# 144 0 days 02:24:43.065000     23.6      58.0    1013.2      True       29.2
#
#      WindDirection  WindSpeed
# 143            142        0.6
# 144            154        1.3
# Temperatura_media  23.700000000000003
# Umidità  52.5
# Piove?  True
# TrackTemp AVG  29.35
# Pressure AVG 1013.2
# Wind Speed AVG 0.95
# Wind Direction AVG 148.0
# Il giro inizia :  0 days 02:24:52.765000
# Il giro finisce a:  0 days 02:26:35.323000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 145 0 days 02:25:42.970000     23.5      58.0    1013.2      True       28.7
#
#      WindDirection  WindSpeed
# 145            147        1.0
# Temperatura_media  23.5
# Umidità  58.0
# Piove?  True
# TrackTemp AVG  28.7
# Pressure AVG 1013.2
# Wind Speed AVG 1.0
# Wind Direction AVG 147.0
# Il giro inizia :  0 days 02:26:35.323000
# Il giro finisce a:  0 days 02:28:16.292000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 146 0 days 02:26:42.969000     23.5      62.0    1013.2      True       28.4
# 147 0 days 02:27:42.968000     23.3      62.0    1013.2      True       28.2
#
#      WindDirection  WindSpeed
# 146            132        1.3
# 147            146        1.8
# Temperatura_media  23.4
# Umidità  62.0
# Piove?  True
# TrackTemp AVG  28.299999999999997
# Pressure AVG 1013.2
# Wind Speed AVG 1.55
# Wind Direction AVG 139.0
# Il giro inizia :  0 days 02:28:16.292000
# Il giro finisce a:  0 days 02:29:55.878000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 148 0 days 02:28:42.967000     23.1      65.0    1013.2      True       27.7
# 149 0 days 02:29:42.981000     23.0      65.0    1013.2      True       27.7
#
#      WindDirection  WindSpeed
# 148            145        1.7
# 149            146        1.7
# Temperatura_media  23.05
# Umidità  65.0
# Piove?  True
# TrackTemp AVG  27.7
# Pressure AVG 1013.2
# Wind Speed AVG 1.7
# Wind Direction AVG 145.5
# Il giro inizia :  0 days 02:29:55.878000
# Il giro finisce a:  0 days 02:31:39.167000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 150 0 days 02:30:42.980000     23.0      66.0    1013.2      True       27.2
#
#      WindDirection  WindSpeed
# 150            141        1.6
# Temperatura_media  23.0
# Umidità  66.0
# Piove?  True
# TrackTemp AVG  27.2
# Pressure AVG 1013.2
# Wind Speed AVG 1.6
# Wind Direction AVG 141.0
# Il giro inizia :  0 days 02:31:39.167000
# Il giro finisce a:  0 days 02:33:17.469000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 151 0 days 02:31:42.979000     23.1      67.0    1013.2      True       27.4
# 152 0 days 02:32:42.978000     23.1      66.0    1013.2      True       27.4
#
#      WindDirection  WindSpeed
# 151            134        1.6
# 152            146        1.6
# Temperatura_media  23.1
# Umidità  66.5
# Piove?  True
# TrackTemp AVG  27.4
# Pressure AVG 1013.2
# Wind Speed AVG 1.6
# Wind Direction AVG 140.0
# Il giro inizia :  0 days 02:33:17.469000
# Il giro finisce a:  0 days 02:34:55.542000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 153 0 days 02:33:42.993000     23.2      66.0    1013.2      True       27.3
# 154 0 days 02:34:42.992000     23.1      65.0    1013.2      True       27.4
#
#      WindDirection  WindSpeed
# 153            142        1.7
# 154            152        1.7
# Temperatura_media  23.15
# Umidità  65.5
# Piove?  True
# TrackTemp AVG  27.35
# Pressure AVG 1013.2
# Wind Speed AVG 1.7
# Wind Direction AVG 147.0
# Il giro inizia :  0 days 02:34:55.542000
# Il giro finisce a:  0 days 02:36:31.835000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 155 0 days 02:35:42.975000     23.1      65.0    1013.2      True       27.6
#
#      WindDirection  WindSpeed
# 155            136        1.7
# Temperatura_media  23.1
# Umidità  65.0
# Piove?  True
# TrackTemp AVG  27.6
# Pressure AVG 1013.2
# Wind Speed AVG 1.7
# Wind Direction AVG 136.0
# Il giro inizia :  0 days 02:36:31.835000
# Il giro finisce a:  0 days 02:38:11.302000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 156 0 days 02:36:42.990000     23.3      64.0    1013.2      True       27.7
# 157 0 days 02:37:42.973000     23.3      63.0    1013.2     False       27.8
#
#      WindDirection  WindSpeed
# 156            143        1.7
# 157            138        2.0
# Temperatura_media  23.3
# Umidità  63.5
# Piove?  True
# TrackTemp AVG  27.75
# Pressure AVG 1013.2
# Wind Speed AVG 1.85
# Wind Direction AVG 140.5
# Il giro inizia :  0 days 02:38:11.302000
# Il giro finisce a:  0 days 02:39:43.223000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 158 0 days 02:38:43.003000     23.4      62.0    1013.2     False       28.1
# 159 0 days 02:39:42.971000     23.5      63.0    1013.2     False       28.2
#
#      WindDirection  WindSpeed
# 158            151        1.6
# 159            140        1.7
# Temperatura_media  23.45
# Umidità  62.5
# Piove?  False
# TrackTemp AVG  28.15
# Pressure AVG 1013.2
# Wind Speed AVG 1.65
# Wind Direction AVG 145.5
# Il giro inizia :  0 days 02:39:43.223000
# Il giro finisce a:  0 days 02:41:16.416000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 160 0 days 02:40:42.970000     23.5      62.0    1013.0     False       28.7
#
#      WindDirection  WindSpeed
# 160            148        1.7
# Temperatura_media  23.5
# Umidità  62.0
# Piove?  False
# TrackTemp AVG  28.7
# Pressure AVG 1013.0
# Wind Speed AVG 1.7
# Wind Direction AVG 148.0
# Il giro inizia :  0 days 02:41:16.416000
# Il giro finisce a:  0 days 02:43:14.679000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 161 0 days 02:41:42.968000     23.6      59.0    1013.0     False       29.0
# 162 0 days 02:42:42.999000     23.6      58.0    1013.0     False       29.2
#
#      WindDirection  WindSpeed
# 161            137        2.0
# 162            136        2.0
# Temperatura_media  23.6
# Umidità  58.5
# Piove?  False
# TrackTemp AVG  29.1
# Pressure AVG 1013.0
# Wind Speed AVG 2.0
# Wind Direction AVG 136.5
# Il giro inizia :  0 days 02:43:14.679000
# Il giro finisce a:  0 days 02:44:43.694000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 163 0 days 02:43:43.013000     23.7      57.0    1013.0     False       29.6
# 164 0 days 02:44:43.012000     23.8      57.0    1013.0     False       30.0
#
#      WindDirection  WindSpeed
# 163            139        1.3
# 164            138        1.3
# Temperatura_media  23.75
# Umidità  57.0
# Piove?  False
# TrackTemp AVG  29.8
# Pressure AVG 1013.0
# Wind Speed AVG 1.3
# Wind Direction AVG 138.5
# Il giro inizia :  0 days 02:44:43.694000
# Il giro finisce a:  0 days 02:46:16.048000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 165 0 days 02:45:43.011000     23.8      57.0    1013.0     False       30.0
#
#      WindDirection  WindSpeed
# 165            125        1.1
# Temperatura_media  23.8
# Umidità  57.0
# Piove?  False
# TrackTemp AVG  30.0
# Pressure AVG 1013.0
# Wind Speed AVG 1.1
# Wind Direction AVG 125.0
# Il giro inizia :  0 days 02:46:16.048000
# Il giro finisce a:  0 days 02:47:43.185000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 166 0 days 02:46:43.026000     23.8      56.0    1013.0     False       30.3
# 167 0 days 02:47:43.040000     23.9      57.0    1013.0     False       30.4
#
#      WindDirection  WindSpeed
# 166            146        1.5
# 167            138        1.5
# Temperatura_media  23.85
# Umidità  56.5
# Piove?  False
# TrackTemp AVG  30.35
# Pressure AVG 1013.0
# Wind Speed AVG 1.5
# Wind Direction AVG 142.0
# Il giro inizia :  0 days 02:47:43.185000
# Il giro finisce a:  0 days 02:49:11.139000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 168 0 days 02:48:43.055000     23.9      57.0    1012.9     False       30.7
#
#      WindDirection  WindSpeed
# 168            136        1.7
# Temperatura_media  23.9
# Umidità  57.0
# Piove?  False
# TrackTemp AVG  30.7
# Pressure AVG 1012.9
# Wind Speed AVG 1.7
# Wind Direction AVG 136.0
# Il giro inizia :  0 days 02:49:11.139000
# Il giro finisce a:  0 days 02:50:39.107000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 169 0 days 02:49:43.069000     24.0      59.0    1012.9     False       30.7
#
#      WindDirection  WindSpeed
# 169            144        1.3
# Temperatura_media  24.0
# Umidità  59.0
# Piove?  False
# TrackTemp AVG  30.7
# Pressure AVG 1012.9
# Wind Speed AVG 1.3
# Wind Direction AVG 144.0
# Il giro inizia :  0 days 02:50:39.107000
# Il giro finisce a:  0 days 02:52:08.183000
#                       Time  AirTemp  Humidity  Pressure  Rainfall  TrackTemp  \
# 170 0 days 02:50:43.068000     23.9      58.0    1012.9     False       30.7
# 171 0 days 02:51:43.083000     23.9      56.0    1012.9     False       30.7
#
#      WindDirection  WindSpeed
# 170            135        1.5
# 171            134        1.3
# Temperatura_media  23.9
# Umidità  57.0
# Piove?  False
# TrackTemp AVG  30.7
# Pressure AVG 1012.9
# Wind Speed AVG 1.4
# Wind Direction AVG 134.5

# %% [markdown]
# Show df copy

# %%
driver_laps
# Out:
#                       Time Driver DriverNumber                LapTime  \
# 442 0 days 01:03:40.909000    SAR            2 0 days 00:01:37.689000
# 443 0 days 01:05:00.567000    SAR            2 0 days 00:01:19.658000
# 444 0 days 01:06:20.786000    SAR            2 0 days 00:01:20.219000
# 445 0 days 01:07:41.032000    SAR            2 0 days 00:01:20.246000
# 446 0 days 01:09:01.246000    SAR            2 0 days 00:01:20.214000
# ..                     ...    ...          ...                    ...
# 513 0 days 02:46:16.048000    SAR            2 0 days 00:01:32.354000
# 514 0 days 02:47:43.185000    SAR            2 0 days 00:01:27.137000
# 515 0 days 02:49:11.139000    SAR            2 0 days 00:01:27.954000
# 516 0 days 02:50:39.107000    SAR            2 0 days 00:01:27.968000
# 517 0 days 02:52:08.183000    SAR            2 0 days 00:01:29.076000
#
#      LapNumber  Stint PitOutTime PitInTime            Sector1Time  \
# 442        1.0    1.0        NaT       NaT                    NaT
# 443        2.0    1.0        NaT       NaT 0 days 00:00:21.209000
# 444        3.0    1.0        NaT       NaT 0 days 00:00:21.279000
# 445        4.0    1.0        NaT       NaT 0 days 00:00:21.243000
# 446        5.0    1.0        NaT       NaT 0 days 00:00:21.315000
# ..         ...    ...        ...       ...                    ...
# 513       72.0    4.0        NaT       NaT 0 days 00:00:26.671000
# 514       73.0    4.0        NaT       NaT 0 days 00:00:22.512000
# 515       74.0    4.0        NaT       NaT 0 days 00:00:23.755000
# 516       75.0    4.0        NaT       NaT 0 days 00:00:22.797000
# 517       76.0    4.0        NaT       NaT 0 days 00:00:24.523000
#
#                Sector2Time  ... DeletedReason FastF1Generated IsAccurate  \
# 442 0 days 00:00:44.183000  ...                         False      False
# 443 0 days 00:00:37.307000  ...                         False       True
# 444 0 days 00:00:37.588000  ...                         False       True
# 445 0 days 00:00:37.688000  ...                         False       True
# 446 0 days 00:00:37.650000  ...                         False       True
# ..                     ...  ...           ...             ...        ...
# 513 0 days 00:00:44.166000  ...                         False       True
# 514 0 days 00:00:42.573000  ...                         False       True
# 515 0 days 00:00:42.097000  ...                         False       True
# 516 0 days 00:00:41.457000  ...                         False       True
# 517 0 days 00:00:41.980000  ...                         False       True
#
#     AirTemp  Humidity  Pressure  Rainfall  Track_Temp WindDirection WindSpeed
# 442   25.20      44.0   1013.40     False       43.10         153.0      0.80
# 443   25.20      44.5   1013.45     False       42.95          57.0      0.90
# 444   25.30      45.0   1013.40     False       42.80          18.0      1.00
# 445   25.40      45.0   1013.50     False       42.80         115.0      1.00
# 446   25.45      44.0   1013.50     False       42.40         146.5      1.15
# ..      ...       ...       ...       ...         ...           ...       ...
# 513   23.80      57.0   1013.00     False       30.00         125.0      1.10
# 514   23.85      56.5   1013.00     False       30.35         142.0      1.50
# 515   23.90      57.0   1012.90     False       30.70         136.0      1.70
# 516   24.00      59.0   1012.90     False       30.70         144.0      1.30
# 517   23.90      57.0   1012.90     False       30.70         134.5      1.40
#
# [76 rows x 38 columns]

# %% [markdown]
# Generate csv from df

# %%
driver_laps.to_csv(f'driver_laps_{driver}.csv', index=False)
